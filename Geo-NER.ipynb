# %%
from Utils import NER_Utils
import torch
from transformers import RobertaForTokenClassification, RobertaTokenizerFast, TrainingArguments, Trainer
from Reader import obtain_dataset

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    device = torch.device('cuda')
print("Current Device:", torch.cuda.current_device(), torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# CUDA available: True
# Current Device: 0 NVIDIA GeForce RTX 4070 Ti

# %%
datasets, label_list, label2id, id2label = obtain_dataset("OzRock", "BIO")

# %%
# Load tokenizer and model
model_name = 'roberta-base'
tokenizer = RobertaTokenizerFast.from_pretrained(model_name, add_prefix_space=True, use_fast=True)
model = RobertaForTokenClassification.from_pretrained(model_name, num_labels=len(label_list), label2id=label2id, id2label=id2label)
# Out:
# d:\GeoTKG\venv\Lib\site-packages\huggingface_hub\file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForTokenClassification: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="results/Geo-NER",
    logging_dir="logs/Geo-NER",
    evaluation_strategy="steps",
    save_strategy="steps",
    logging_steps=500,
    num_train_epochs=1,
    save_total_limit=1,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    learning_rate=5e-5,
    load_best_model_at_end=True,
    metric_for_best_model="f1"
)

# %%
utils = NER_Utils(tokenizer, label_list)
datasets = utils.tokenize_datasets(datasets)
# Out:
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'label', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 31942
#     })
#     eval: Dataset({
#         features: ['tokens', 'label', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 2000
#     })
# })

# %%
geo_ner = Trainer(
    model=model,
    args=training_args,
    compute_metrics=utils.compute_metrics,
    data_collator=utils.data_collator,
    tokenizer=tokenizer,
    train_dataset=datasets["train"],
    eval_dataset=datasets["eval"],
)

# %%
history = geo_ner.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens. If tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# d:\GeoTKG\venv\Lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 31942
#   Num Epochs = 1
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1997
#   Number of trainable parameters = 124065037
#   0%|          | 0/1997 [00:00<?, ?it/s]
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens. If tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 32
# {'loss': 0.1425, 'learning_rate': 3.7481221832749126e-05, 'epoch': 0.25}
#   0%|          | 0/63 [00:00<?, ?it/s]
# Saving model checkpoint to results/Geo-NER\checkpoint-500
# Configuration saved in results/Geo-NER\checkpoint-500\config.json
# {'eval_loss': 0.21925972402095795, 'eval_precision': 0.7356902356902357, 'eval_recall': 0.720065909923105, 'eval_f1': 0.7277942264988897, 'eval_runtime': 3.8228, 'eval_samples_per_second': 523.175, 'eval_steps_per_second': 16.48, 'epoch': 0.25}
# Model weights saved in results/Geo-NER\checkpoint-500\pytorch_model.bin
# tokenizer config file saved in results/Geo-NER\checkpoint-500\tokenizer_config.json
# Special tokens file saved in results/Geo-NER\checkpoint-500\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens. If tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 32
# {'loss': 0.0503, 'learning_rate': 2.4962443665498246e-05, 'epoch': 0.5}
#   0%|          | 0/63 [00:00<?, ?it/s]
# Saving model checkpoint to results/Geo-NER\checkpoint-1000
# Configuration saved in results/Geo-NER\checkpoint-1000\config.json
# {'eval_loss': 0.2362024486064911, 'eval_precision': 0.7608575124745888, 'eval_recall': 0.7537532039545954, 'eval_f1': 0.7572886967718202, 'eval_runtime': 3.7179, 'eval_samples_per_second': 537.943, 'eval_steps_per_second': 16.945, 'epoch': 0.5}
# Model weights saved in results/Geo-NER\checkpoint-1000\pytorch_model.bin
# tokenizer config file saved in results/Geo-NER\checkpoint-1000\tokenizer_config.json
# Special tokens file saved in results/Geo-NER\checkpoint-1000\special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens. If tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 32
# {'loss': 0.0344, 'learning_rate': 1.2443665498247372e-05, 'epoch': 0.75}
#   0%|          | 0/63 [00:00<?, ?it/s]
# Saving model checkpoint to results/Geo-NER\checkpoint-1500
# Configuration saved in results/Geo-NER\checkpoint-1500\config.json
# {'eval_loss': 0.25111204385757446, 'eval_precision': 0.7720999627004849, 'eval_recall': 0.7579641157085317, 'eval_f1': 0.7649667405764967, 'eval_runtime': 3.7348, 'eval_samples_per_second': 535.498, 'eval_steps_per_second': 16.868, 'epoch': 0.75}
# Model weights saved in results/Geo-NER\checkpoint-1500\pytorch_model.bin
# tokenizer config file saved in results/Geo-NER\checkpoint-1500\tokenizer_config.json
# Special tokens file saved in results/Geo-NER\checkpoint-1500\special_tokens_map.json
# Deleting older checkpoint [results\Geo-NER\checkpoint-500] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from results/Geo-NER\checkpoint-1500 (score: 0.7649667405764967).
# Deleting older checkpoint [results\Geo-NER\checkpoint-1000] due to args.save_total_limit
# Deleting older checkpoint [results\Geo-NER\checkpoint-1500] due to args.save_total_limit
# {'train_runtime': 365.6769, 'train_samples_per_second': 87.35, 'train_steps_per_second': 5.461, 'train_loss': 0.06364029410127765, 'epoch': 1.0}

# %%
geo_ner.evaluate(datasets["eval"])
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tokens. If tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 32
#   0%|          | 0/63 [00:00<?, ?it/s]
# {'eval_loss': 0.25111204385757446,
#  'eval_precision': 0.7720999627004849,
#  'eval_recall': 0.7579641157085317,
#  'eval_f1': 0.7649667405764967,
#  'eval_runtime': 3.9729,
#  'eval_samples_per_second': 503.413,
#  'eval_steps_per_second': 15.858,
#  'epoch': 1.0}

# %%
geo_ner.save_model("results/Geo-NER")
geo_ner.tokenizer.save_pretrained("results/Geo-NER")
# Out:
# Saving model checkpoint to results/Geo-NER
# Configuration saved in results/Geo-NER\config.json
# Model weights saved in results/Geo-NER\pytorch_model.bin
# tokenizer config file saved in results/Geo-NER\tokenizer_config.json
# Special tokens file saved in results/Geo-NER\special_tokens_map.json
# tokenizer config file saved in results/Geo-NER\tokenizer_config.json
# Special tokens file saved in results/Geo-NER\special_tokens_map.json
# ('results/Geo-NER\\tokenizer_config.json',
#  'results/Geo-NER\\special_tokens_map.json',
#  'results/Geo-NER\\vocab.json',
#  'results/Geo-NER\\merges.txt',
#  'results/Geo-NER\\added_tokens.json',
#  'results/Geo-NER\\tokenizer.json')

# %%
encodings=tokenizer(list(datasets["eval"]["tokens"]), padding=True, truncation=True, return_tensors="pt", is_split_into_words=True)
encodings.to(device)
with torch.no_grad():
    outputs = geo_ner.model(**encodings)
    logits = outputs.logits
    predictions = torch.argmax(logits, dim=-1)

utils.classification_rep(predictions, datasets["eval"]["label"], "micro", encodings)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       5     logits = outputs.logits
#       6     predictions = torch.argmax(logits, dim=-1)
# ----> 8 utils.classification_rep(predictions, datasets["eval"]["label"], "micro", encodings)
#
# File d:\GeoTKG\scripts\Utils.py:46, in Utils.classification_rep(self, predictions, labels, average, encodings)
#      44     predicted_labels.append(aligned_preds)
#      45     true_labels.append(aligned_labels)
# ---> 46 print(classification_report(true_labels, predicted_labels, average=average))
#
# TypeError: classification_report() got an unexpected keyword argument 'average'
