# %%
import torch
x = torch.tensor([[[1,2],[2,3],[-1,-1]],
                  [[1,2],[2,3],[3,4]]])

r = torch.tensor([[7,8,-1],[4,5,6]]).unsqueeze(-1)

torch.cat([x,r], -1)
# Out:
# tensor([[[ 1,  2,  7],
#          [ 2,  3,  8],
#          [-1, -1, -1]],
#
#         [[ 1,  2,  4],
#          [ 2,  3,  5],
#          [ 3,  4,  6]]])

# %%
r.unsqueeze(-1)
# Out:
# tensor([[[ 7],
#          [ 8],
#          [-1]],
#
#         [[ 4],
#          [ 5],
#          [ 6]]])

# %%
torch.tensor([1,2,3]).shape
# Out:
# torch.Size([3])
