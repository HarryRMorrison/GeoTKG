# %%
from Reader import obtain_combined_dataset
datasets, label_list, label2id, id2label = obtain_combined_dataset(["MATRES"], "TempRel")

# %%
label2id
# Out:
# {'AFTER': 0, 'BEFORE': 1, 'EQUAL': 2, 'VAGUE': 3}

# %%
import numpy as np
values, counts = np.unique(datasets["train"]['label'], return_counts=True)

# %%
values
# Out:
# array(['AFTER', 'BEFORE', 'EQUAL', 'VAGUE'], dtype='<U6')

# %%
counts
# Out:
# array([3279, 4948,  338, 1176], dtype=int64)
